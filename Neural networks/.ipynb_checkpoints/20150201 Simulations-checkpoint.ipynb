# %%
#import matplotlib.pyplot as plt

import pandas as pd
#pd.options.display.mpl_style = 'default'


import numpy as np
explanatory_vars = ["x"+str(i) for i in range(1,6)]
df_simple = pd.DataFrame((np.random.rand(10000, len(explanatory_vars))-0.5)*20, columns=explanatory_vars)
df_nonlinear = pd.DataFrame((np.random.rand(10000,len(explanatory_vars))-0.5)*5, columns=explanatory_vars)

# %%
import scipy.special as special

#This is the real data generating process
df_simple["x"] = 3 + 0.7*df_simple["x1"] + 1.5*df_simple["x2"]

#Calculate the probability from the logit function
df_simple["yprob"] = special.expit(df_simple["x"])

#Calculate some uniform draws from error
df_simple["e"] = np.random.rand(df_simple.shape[0])

#Compute the observed data - i.e. 1s and 0s - according to generated probabilities
df_simple["y"] = 1
df_simple["y"]= df_simple["y"].where(df_simple["yprob"]>df_simple["e"],0)
df_simple.head()
# Out:
#          x1        x2        x3        x4        x5          x     yprob  \
# 0 -2.575080 -2.510980 -6.663202 -0.046169  4.434715  -2.569026  0.071159
# 1 -8.692337  9.045746  9.560565 -6.137439  0.812052  10.483983  0.999972
# 2  6.068078 -1.774638 -9.479213  1.389766 -2.242257   4.585698  0.989906
# 3  8.364656 -3.299582 -7.254161  8.675456  8.614657   3.905887  0.980274
# 4 -5.826468  4.441912  5.461402  2.149168  6.645128   5.584340  0.996258
#
#           e  y
# 0  0.536394  0
# 1  0.393033  1
# 2  0.196094  1
# 3  0.287687  1
# 4  0.979265  1

# %%
import scipy.special as special

#This is the real data generating process
df_nonlinear["x"] =3*df_nonlinear["x1"] + 1*df_nonlinear["x2"]  + 3*df_nonlinear["x1"]*df_nonlinear["x2"] -0.2*df_nonlinear["x1"]**3

#Calculate the probability from the logit function
df_nonlinear["yprob"] = special.expit(df_nonlinear["x"])

#Calculate some uniform draws from error
df_nonlinear["e"] = np.random.rand(df_nonlinear.shape[0])

#Compute the observed data - i.e. 1s and 0s - according to generated probabilities
df_nonlinear["y"] = 1
df_nonlinear["y"]= df_nonlinear["y"].where(df_nonlinear["yprob"]>df_nonlinear["e"],0)

# %% [markdown]
# ##Estimating a nice simple logit model

# %%
# %matplotlib inline
#df_simple.plot(kind='scatter', x='x1', y='x2',c=df_simple['y'], edgecolors='none', alpha=0.3,figsize=[5,5],s=5,xlim=(-10,10), ylim=(-10,10));

# %% [markdown]
# Plot the data with the real (not estimated) decision boundary overlyed

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
fig, ax = plt.subplots()
plot = ax.scatter(df_simple["x1"], df_simple["x2"],c=df_simple['y'], edgecolors='none', alpha=0.1,s=5)


x1 = np.arange(-10, 10, 0.01)
x2 = np.arange(-10, 10, 0.01)
xx1, xx2 = np.meshgrid(x1, x2)
z = 3 + 0.7*xx1+1.5*xx2

ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
ax.contour(x1,x2,z,1)

fig = mpl.pyplot.gcf()
fig.set_figheight(5)
fig.set_figwidth(5)

# %%
import statsmodels.api as sm
import statsmodels.tools.tools as tools

logit = sm.Logit(df_simple['y'], tools.add_constant(df_simple[explanatory_vars]))
logit_results = logit.fit()
print logit_results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.107000
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               100000
# Model:                          Logit   Df Residuals:                    99994
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 01 Feb 2015   Pseudo R-squ.:                  0.8409
# Time:                        18:35:14   Log-Likelihood:                -10700.
# converged:                       True   LL-Null:                       -67253.
#                                         LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          3.0466      0.034     88.586      0.000         2.979     3.114
# x1             0.7110      0.008     94.275      0.000         0.696     0.726
# x2             1.5242      0.015    102.926      0.000         1.495     1.553
# x3            -0.0027      0.003     -0.903      0.366        -0.009     0.003
# x4            -0.0033      0.003     -1.087      0.277        -0.009     0.003
# x5             0.0028      0.003      0.910      0.363        -0.003     0.009
# ==============================================================================

# %% [markdown]
# ##Estimating a much more complex function

# %%
#df_nonlinear.plot(kind='scatter', x='x1', y='x2',c=df_nonlinear['y'], edgecolors='none', alpha=0.2,figsize=[5,5],s=2.5,xlim=(-2.5,2.5), ylim=(-2.5,2.5));

# %%
#Show the real decision boundary (i.e. the one which yields the highest accuracy)
fig, ax = plt.subplots()
plot = ax.scatter(df_nonlinear["x1"], df_nonlinear["x2"],c=df_nonlinear['y'], edgecolors='none', alpha=0.1,s=5)

x1 = np.arange(-2.5, 2.5, 0.01)
x2 = np.arange(-2.5, 2.5, 0.01)
xx1, xx2 = np.meshgrid(x1, x2)
z =  3*xx1 + 1*xx2 + 3*xx1*xx2 - 0.2*xx1**3

ax.set_xlim([-2.5,2.5])
ax.set_ylim([-2.5,2.5])
ax.contour(x1,x2,z,1)
fig = mpl.pyplot.gcf()
fig.set_figheight(5)
fig.set_figwidth(5)

# %%
import statsmodels.api as sm
import statsmodels.tools.tools as tools

logit = sm.Logit(df_nonlinear['y'], tools.add_constant(df_nonlinear[explanatory_vars]))
logit_results = logit.fit()
print logit_results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.637726
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               100000
# Model:                          Logit   Df Residuals:                    99994
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 01 Feb 2015   Pseudo R-squ.:                 0.07479
# Time:                        18:35:16   Log-Likelihood:                -63773.
# converged:                       True   LL-Null:                       -68927.
#                                         LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         -0.1945      0.007    -29.029      0.000        -0.208    -0.181
# x1             0.4144      0.005     86.022      0.000         0.405     0.424
# x2             0.2312      0.005     49.242      0.000         0.222     0.240
# x3            -0.0011      0.005     -0.228      0.820        -0.010     0.008
# x4            -0.0060      0.005     -1.299      0.194        -0.015     0.003
# x5            -0.0063      0.005     -1.363      0.173        -0.015     0.003
# ==============================================================================

# %%
#Plot the decision boundary yielded by a linear decision boundary
fig, ax = plt.subplots()
plot = ax.scatter(df_nonlinear["x1"], df_nonlinear["x2"],c=df_nonlinear['y'], edgecolors='none', alpha=0.1,s=5)

x1 = np.arange(-2.5, 2.5, 0.01)
x2 = np.arange(-2.5, 2.5, 0.01)
xx1, xx2 = np.meshgrid(x1, x2)
z =  -0.2 + 0.43*xx1+0.24*xx2

ax.set_xlim([-2.5,2.5])
ax.set_ylim([-2.5,2.5])
ax.contour(x1,x2,z,1)
fig = mpl.pyplot.gcf()
fig.set_figheight(5)
fig.set_figwidth(5)

# %% [markdown]
# ##Crack out scikit learn
#
# To do:
#
# *  Use scikit learn to fit a simple logit model and plot decision boundary
# *  Use scikit learn to fit a more complex model?
# *  Use a neural network to fit the model

# %%
import scipy
from sklearn import svm

# %%
clf = svm.SVC(kernel = 'linear',  gamma=0.7, C=1 )
X = np.array(df_nonlinear[["x1","x2"]])
y = np.array(df_nonlinear["y"])
clf.fit(X,y)

# %%
np.array(df_nonlinear["y"])
# Out:
# array([1, 0, 0, ..., 1, 1, 0], dtype=int64)

# %%
# Out:
#              x1        x2
# 0      2.087233  0.366178
# 1     -0.901124 -2.276665
# 2      1.385365 -0.086322
# 3     -2.033300  0.560079
# 4     -2.163310  0.944679
# 5     -0.373627 -1.757975
# 6     -0.298932  0.990919
# 7     -0.213416 -0.845267
# 8     -1.401812  0.771349
# 9      1.985251 -1.964479
# 10     1.010243  1.587219
# 11    -1.520369 -2.214559
# 12     1.162107  0.983269
# 13     0.248377 -1.064471
# 14     1.260273  1.089171
# 15     1.046714  0.694671
# 16    -1.307523 -2.431342
# 17    -2.486750 -0.523522
# 18     1.224849  1.385833
# 19     1.819049 -1.291884
# 20    -1.734581  2.467243
# 21     2.348453  2.311114
# 22    -1.875995  1.749988
# 23    -1.446850  2.354934
# 24     1.563316 -1.705914
# 25     0.710879  2.337587
# 26     0.800494 -0.824204
# 27     0.033316  0.222418
# 28     1.871325  0.416692
# 29     0.570062 -0.687817
# ...         ...       ...
# 99970 -0.484531  0.567330
# 99971  1.727576 -1.240412
# 99972  2.208725 -0.007485
# 99973 -1.961358 -0.643265
# 99974  1.005254  2.414365
# 99975 -2.374284 -2.174536
# 99976 -0.674785 -0.239556
# 99977  1.924606 -1.165548
# 99978 -2.036993  0.160821
# 99979  0.495152  0.910809
# 99980  0.449071  2.291643
# 99981 -0.775992  1.360236
# 99982  0.535963  2.151957
# 99983  0.643519  0.415571
# 99984 -0.499670  1.968135
# 99985  1.101617  0.749565
# 99986  1.712419  0.933908
# 99987  0.361682 -0.173251
# 99988  2.431899  0.888234
# 99989 -1.188856  1.285262
# 99990  0.986550 -1.754744
# 99991 -0.724490 -2.445553
# 99992 -1.201911 -2.275495
# 99993  1.753591  2.049616
# 99994  1.860451 -2.375280
# 99995 -1.487634 -0.588149
# 99996  1.057523  1.202805
# 99997  2.405506  0.573388
# 99998  0.924348  1.172580
# 99999  1.374586 -1.225793
#
# [100000 rows x 2 columns]
